# %%
import cv2
from matplotlib import pyplot as plt
import os
import numpy as np
from scipy.spatial import distance

# %%
img1_path = 'sample/5a79c447-4d9d-4daf-81a6-c23a00480a93___Matt.S_CG 2473.JPG'
image = cv2.imread(img1_path)                                # open the image
image_rgb = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)          # convert to RGB
image_rgb2_g = image_rgb[:,:,1]*2  - image_rgb[:,:,0] - image_rgb[:,:,2]
image_rgb2_r = image_rgb[:,:,0]
image_rgb2_b = image_rgb[:,:,2]
image_rgb2 = np.stack((image_rgb2_r, image_rgb2_g, image_rgb2_b), axis=-1)
# mask = cv2.inRange(image_rgb, (100, 100, 100), (160, 150, 160))
plt.imshow(image_rgb2)

# %%
mask
# Out:
# array([[[143, 125, 138],
#         [143, 125, 138],
#         [143, 125, 138],
#         ...,
#         [138, 121, 134],
#         [135, 118, 131],
#         [122, 105, 118]],
#
#        [[148, 130, 143],
#         [147, 129, 142],
#         [146, 128, 141],
#         ...,
#         [149, 132, 145],
#         [148, 131, 144],
#         [133, 116, 129]],
#
#        [[154, 136, 149],
#         [152, 134, 147],
#         [148, 130, 143],
#         ...,
#         [139, 122, 135],
#         [145, 128, 141],
#         [139, 122, 135]],
#
#        ...,
#
#        [[165, 150, 164],
#         [162, 147, 161],
#         [151, 136, 150],
#         ...,
#         [146, 136, 148],
#         [146, 136, 148],
#         [144, 134, 146]],
#
#        [[147, 132, 146],
#         [170, 155, 169],
#         [167, 152, 166],
#         ...,
#         [147, 137, 149],
#         [145, 135, 147],
#         [139, 129, 141]],
#
#        [[165, 150, 164],
#         [166, 151, 165],
#         [141, 126, 140],
# ...
